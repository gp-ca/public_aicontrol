# %%
import pandas as pd

# %%
svm_grid_search_results = None
# %run parameter_optimization_scripts/svm_grid_search.py
# Out:
# Parameter optimization of OneVsRestClassifier SVM
# Starting grid search ... [================================================= ]                      100%

# %%
svm_grid_search_results.to_pickle('grid_search_results\\svm.pkl')
svm_grid_search_results.sort_values(by='score', ascending=False)['params']
# Out:
#       score                                             params transformer  \
# 0  0.980666  {'classifier__estimator__C': 5, 'classifier__e...        none
# 0  0.979628  {'classifier__estimator__C': 5, 'classifier__e...        none
# 0  0.978243  {'classifier__estimator__C': 5, 'classifier__e...         log
# 0  0.976602  {'classifier__estimator__C': 4, 'classifier__e...     arcsinh
# 0  0.973179  {'classifier__estimator__C': 5, 'classifier__e...         log
# 0  0.971727  {'classifier__estimator__C': 5, 'classifier__e...     arcsinh
# 0  0.944019  {'classifier__estimator__C': 5, 'classifier__e...        none
# 0  0.943264  {'classifier__estimator__C': 5, 'classifier__e...        none
# 0  0.280143  {'classifier__estimator__C': 1, 'classifier__e...         log
# 0  0.280143  {'classifier__estimator__C': 1, 'classifier__e...     arcsinh
# 0  0.279547  {'classifier__estimator__C': 1, 'classifier__e...         log
# ...

# %%
rfc_grid_search_results = None
# %run parameter_optimization_scripts/rfc_grid_search.py
# Out:
# Parameter optimization of RFC
# Starting grid search ... [================================================= ]                      100%

# %%
rfc_grid_search_results.to_pickle('grid_search_results\\rfc.pkl')
rfc_grid_search_results.sort_values(by='score', ascending=False)
# Out:
#       score                                             params transformer  \
# 0  0.987031  {'classifier__n_estimators': 120, 'classifier_...        none
# 0  0.987031  {'classifier__n_estimators': 120, 'classifier_...        none
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...        none
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...        none
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...         log
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...         log
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...     arcsinh
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...     arcsinh
# 0  0.986792  {'classifier__n_estimators': 120, 'classifier_...         log
# 0  0.986792  {'classifier__n_estimators': 120, 'classifier_...         log
# 0  0.986792  {'classifier__n_estimators': 120, 'classifier_...     arcsinh
# ...

# %%
rfc_grid_search_results.to_pickle('grid_search_results\\rfc.pkl')
rfc_grid_search_results.sort_values(by='score', ascending=False)
# Out:
#       score                                             params transformer  \
# 0  0.987031  {'classifier__n_estimators': 120, 'classifier_...        none
# 0  0.987031  {'classifier__n_estimators': 120, 'classifier_...        none
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...        none
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...        none
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...         log
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...         log
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...     arcsinh
# 0  0.986873  {'classifier__n_estimators': 70, 'classifier__...     arcsinh
# 0  0.986792  {'classifier__n_estimators': 120, 'classifier_...         log
# 0  0.986792  {'classifier__n_estimators': 120, 'classifier_...         log
# 0  0.986792  {'classifier__n_estimators': 120, 'classifier_...     arcsinh
# ...

# %%
knn_grid_search_results = None
# %run parameter_optimization_scripts/knn_grid_search.py
# Out:
# Parameter optimization of KNN
# Starting grid search ... [================================================= ]                      100%

# %%
knn_grid_search_results.to_pickle('grid_search_results\\knn.pkl')
knn_grid_search_results.sort_values(by='score', ascending=False)
# Out:
#       score                                             params transformer  \
# 0  0.971102  {'classifier__n_jobs': -1, 'classifier__n_neig...        none
# 0  0.969470  {'classifier__n_jobs': -1, 'classifier__n_neig...        none
# 0  0.947292  {'classifier__n_jobs': -1, 'classifier__n_neig...         log
# 0  0.945116  {'classifier__n_jobs': -1, 'classifier__n_neig...     arcsinh
# 0  0.937335  {'classifier__n_jobs': -1, 'classifier__n_neig...         log
# 0  0.932821  {'classifier__n_jobs': -1, 'classifier__n_neig...     arcsinh
# 0  0.932041  {'classifier__n_jobs': -1, 'classifier__n_neig...        none
# 0  0.932041  {'classifier__n_jobs': -1, 'classifier__n_neig...        none
# 0  0.426617  {'classifier__n_jobs': -1, 'classifier__n_neig...         log
# 0  0.426501  {'classifier__n_jobs': -1, 'classifier__n_neig...     arcsinh
# 0  0.424768  {'classifier__n_jobs': -1, 'classifier__n_neig...     arcsinh
# ...
